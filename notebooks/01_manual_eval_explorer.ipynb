# %% [markdown]
# # Manual Evaluation Explorer

# %%
import pandas as pd
from sklearn.metrics import jaccard_score
from pathlib import Path
import sys

module_path = Path("../src/reproscreener")
sys.path.append(str(module_path))
from manual_eval import ManualEvaluationParser

parser = ManualEvaluationParser(str(module_path/"manual_evaluations"))
evaluations = parser.load_all_evaluations()
dataset_names = list(evaluations.keys())
dataset_names
# Out:
# ['abstract', 'agreement_gpt', 'manuscript', 'combined_abstract']

# %%
parser.standardized_metrics.keys()
# Out:
# dict_keys(['problem', 'objective', 'research_method', 'research_questions', 'pseudocode', 'dataset', 'hypothesis', 'prediction', 'code_avail', 'software_dependencies', 'experiment_setup', 'empirical_dataset', 'code_avail_article', 'pwc_link_avail', 'pwc_link_match', 'result_replication_code_avail', 'package', 'wrapper_scripts', 'hardware_specifications', 'will_it_reproduce', 'parsed_readme'])

# %% [markdown]
# ### 1. `abstract`

# %%
df_abstract = evaluations['abstract']
# exclude all columns with names containing "_description"
df_abstract = df_abstract.drop(columns=["evaluation_type", "source_file", "paper_id"]
                               +[col for col in df_abstract.columns if "_description" in col])
df_abstract.head()
# Out:
#             problem  objective  research_method  research_questions  \
# paper_id
# 1606.04671    False      False            False               False
# 1903.09668    False      False             True               False
# 1904.10554    False      False            False               False
# 1908.05659    False      False            False               False
# 1909.00931    False      False            False               False
#
#             pseudocode  dataset  hypothesis  prediction  code_available  \
# paper_id
# 1606.04671       False    False       False       False           False
# 1903.09668       False    False       False       False           False
# 1904.10554       False    False       False       False           False
# 1908.05659       False    False       False       False           False
# 1909.00931       False    False       False       False           False
#
#             software_dependencies  experiment_setup
# paper_id
# 1606.04671                  False             False
# 1903.09668                  False             False
# 1904.10554                  False             False
# 1908.05659                  False             False
# 1909.00931                  False             False

# %%
df_abstract.sum()
# Out:
# problem                  6
# objective                1
# research_method          1
# research_questions       1
# pseudocode               0
# dataset                  1
# hypothesis               0
# prediction               0
# code_available           3
# software_dependencies    0
# experiment_setup         0
# dtype: int64

# %% [markdown]
# ### 1. `agreement_gpt`

# %%
df_agreement_gpt = evaluations["agreement_gpt"]
# exclude all columns with names containing "_description"
df_agreement_gpt = df_agreement_gpt.drop(
    columns=["evaluation_type", "source_file", "paper_id"]
    + [col for col in df_agreement_gpt.columns if "_description" in col]
)
# rename all columns to remove the "gpt_" prefix
df_agreement_gpt = df_agreement_gpt.rename(
    columns={
        col: col.replace("gpt_", "")
        for col in df_agreement_gpt.columns
        if col.startswith("gpt_")
    }
)
df_agreement_gpt.head()
# Out:
#             problem  problem_agreement  objective  objective_agreement  \
# paper_id
# 1606.04671     True               True       True                False
# 1903.09668     True               True       True                 True
# 1904.10554     True               True       True                 True
# 1908.05659     True              False       True                 True
# 1909.00931     True               True       True                 True
#
#             research_method  research_method_agreement  research_questions  \
# paper_id
# 1606.04671             True                      False               False
# 1903.09668             True                       True               False
# 1904.10554             True                       True               False
# 1908.05659            False                       True               False
# 1909.00931             True                       True               False
#
#             research_questions_agreement  pseudocode  pseudocode_agreement  \
# paper_id
# 1606.04671                          True       False                  True
# 1903.09668                          True       False                  True
# 1904.10554                          True       False                  True
# 1908.05659                          True       False                  True
# 1909.00931                          True       False                  True
#
#             ...  hypothesis  hypothesis_agreement  prediction  \
# paper_id    ...
# 1606.04671  ...       False                  True        True
# 1903.09668  ...       False                 False       False
# 1904.10554  ...       False                  True       False
# 1908.05659  ...       False                  True       False
# 1909.00931  ...        True                  True        True
#
#             prediction_agreement  code_available  code_available_agreement  \
# paper_id
# 1606.04671                  True           False                      True
# 1903.09668                  True           False                      True
# 1904.10554                  True           False                      True
# 1908.05659                  True           False                      True
# 1909.00931                 False           False                      True
#
#             software_dependencies  software_dependencies_agreement  \
# paper_id
# 1606.04671                  False                             True
# 1903.09668                  False                             True
# 1904.10554                  False                             True
# 1908.05659                  False                             True
# 1909.00931                   True                             True
#
#             experiment_setup  experiment_setup_agreement
# paper_id
# 1606.04671             False                        True
# 1903.09668              True                       False
# 1904.10554             False                       False
# 1908.05659             False                        True
# 1909.00931              True                       False
#
# [5 rows x 22 columns]

# %% [markdown]
# ### 1. `manuscript`

# %% [markdown]
# ### 1. `abstract`

# %% [markdown]
# ### 1. `combined_abstract`
