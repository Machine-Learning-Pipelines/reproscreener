# %%
import json
import pandas as pd
with open("../guidance/gunderson-2018-revised/main-codebook.json", "r") as read_file:
    df_json = pd.json_normalize(json.load(read_file), record_path=["variables"])

# %%
df_json
# Out:
#                        name         factor  \
# 0                   Problem         Method
# 1                 Objective         Method
# 2           Research Method         Method
# 3        Research questions         Method
# 4                Pseudocode         Method
# 5             Training data           Data
# 6           Validation data           Data
# 7                 Test data           Data
# 8                   Results           Data
# 9                Hypothesis     Experiment
# 10               Prediction     Experiment
# 11       Method source code     Experiment
# 12  Hardware specifications     Experiment
# 13    Software dependencies     Experiment
# 14         Experiment setup     Experiment
# 15   Experiment source code     Experiment
# 16              Affiliation  Miscellaneous
#
#                                           description  explicit  \
# 0             The problem the research seeks to solve      True
# 1                       The objective of the research      True
# 2                            The research method used      True
# 3                      The research question(s) asked      True
# 4                  Method described using pseudo code     False
# 5             The problem the research seeks to solve     False
# 6                       The objective of the research     False
# 7                            The research method used     False
# 8                      The research question(s) asked     False
# 9                   The hypothesis being investigated      True
# 10              Predictions related to the hypotheses      True
# 11                        Is the method open sourced?     False
# 12                                      Hardware used     False
# 13                           For method or experiment     False
# 14  Is the setup including hyper-parameters descri...     False
# 15               Is the experiment code open sourced?     False
# 16  The affiliation of the authors - Academia: (0)...      True
#
#                                           explanation custom
# 0   This variable case-insensitively matches 'prob...    NaN
# 1                                                 NaN    NaN
# 2                                                 NaN    NaN
# 3                                                 NaN    NaN
# 4                                                 NaN    NaN
# 5                                                 NaN    NaN
# 6                                                 NaN    NaN
# 7                                                 NaN    NaN
# 8                                                 NaN    NaN
# 9                                                 NaN    NaN
# 10                                                NaN    NaN
# 11                                                NaN    NaN
# 12                                                NaN    NaN
# 13                                                NaN    NaN
# 14                                                NaN    NaN
# 15                                                NaN    NaN
# 16                                                NaN   True

# %% [markdown]
# ### Comparing scraping conditions

# %%
path_corpus_and = Path("../case-studies/arxiv-corpus/mine50-and/")
eval_and = pd.read_csv(path_corpus_and / 'output/repro_eval_tex.csv')[['id', 'link_count', 'found_links']]

# print ids of papers in eval_andor and eval_and
# eval_andor['id'].values, eval_and['id'].values
eval_and_links = eval_and[eval_and['link_count'] > 0]
eval_and_links
# Out:
#             id  link_count                                        found_links
# 3   2010.04261           1   ['https://github.com/goodfeli/dlbook_notation/']
# 5   2011.11576           5  ['https://github.com/jpbrooks/conjecturing.', ...
# 9   2106.01528           5  ['https://github.com/dereklhansen/flowselect}{...
# 11  2107.01131           8  ['https://github.com/qingguo666/FLO', 'https:/...
# 12  2109.01372           2  ['https://dataiku-research.github.io/cardinal/...
# 13  2109.12784           1  ['https://github.com/tliu1997/TI-SVM}{https://...
# 18  2202.00293           1  ['https://github.com/rodsveiga/phdiag_sgd}{htt...
# 19  2202.04136           1  ['https://github.com/nyukat/generative-multita...
# 20  2202.10574           1       ['https://github.com/RunzheStat/CausalMARL']
# 21  2203.01382           1           ['https://github.com/ChengYuHsieh/Nemo']
# 22  2203.02016           2  ['https://github.com/yannadani/cbed}{https://g...
# 25  2204.04452           1  ['https://gitlab.epfl.ch/sacs/distributed-ml/n...
# 26  2205.10772           2  ['https://github.com/meta-inf/fil}.', 'https:/...
# 29  2205.11361           1  ['https://github.com/JonasGeiping/fullbatchtra...
# 30  2205.12900           2  ['https://github.com/yuxiangw/autodp', 'https:...
# 32  2206.00730           1  ['https://github.com/deepmind/deepmind-researc...
# 33  2206.01900           2  ['https://github.com/TGV-CRN/TGV-CRN', 'https:...
# 34  2206.02829           1  ['https://github.com/YangRui2015/RORL}{https:/...
# 35  2206.02957           2  ['https://github.com/MarioTheOne/GRETEL}.', 'h...
# 40  2207.05219           1       ['https://github.com/facebookresearch/nle}']
# 42  2207.09239           1  ['https://github.com/amazon-research/assaying-...
# 44  2208.06120           2  ['https://github.com/IdahoLabResearch/BIhNNs}{...
# 46  2208.11246           2  ['https://github.com/Hong-Ming/ScaledSGD}.{]',...
# 48  2209.07067           1  ['https://github.com/Healthy-AI/glupts}{https:...
# 49  2209.10715           3  ['https://github.com/rafaol/batch-bore-with-gu...

# %%
# get ids of rows that are not in both eval_andor and eval_and
eval_andor[~eval_andor['id'].isin(eval_and['id'])][['id', 'link_count', 'found_links']]
# Out:
#             id  link_count                                        found_links
# 0   1606.04671           0                                                 []
# 4   1909.00931           3  ['https://github.com/lanwuwei/Twitter-URL-Corp...
# 5   1911.03867           0                                                 []
# 6   2002.05905           0                                                 []
# 7   2004.05258           0                                                 []
# 8   2009.01947           1  ['https://gitlab.com/luciacyx/nm-adaptive-code...
# 12  2012.09302           1        ['https://github.com/ain-soph/trojanzoo}.']
# 15  2104.11893           0                                                 []
# 16  2104.12546           1            ['https://github.com/pcm-dpc/COVID-19']
# 17  2105.01099           0                                                 []
# 18  2105.01937           1                ['https://briang13.github.io/FLEX']
# 21  2106.03157           0                                                 []
# 22  2106.03725           0                                                 []
# 23  2106.06927           1  ['https://github.com/renanrojasg/adv_robust_au...
# 24  2106.07704           4  ['https://github.com/HanGuo97/soft-Q-learning-...
# 25  2106.10898           0                                                 []
# 26  2106.12177           0                                                 []
# 28  2106.13823           0                                                 []
# 30  2108.09779           2  ['https://s2r2-ig.github.io', 'https://s2r2-ig...
# 33  2110.02343           0                                                 []
# 34  2110.02474           0                                                 []
# 36  2110.05169           1   ['https://github.com/goodfeli/dlbook_notation.']
# 37  2110.08255           0                                                 []
# 38  2110.08432           4  ['https://github.com/dragen1860/MAML-Pytorch',...
# 39  2110.09902           1   ['https://github.com/tenghuilee/nnvolterra.git']
# 42  2111.02997           1       ['https://github.com/ShangtongZhang/DeepRL']
# 43  2111.03664           1  ['https://github.com/clovaai/deep-text-recogni...
# 44  2111.08356           0                                                 []
# 45  2111.12673           0                                                 []
# 46  2111.15449           1          ['https://github.com/TianYuZu/POD-Loss.']
# 47  2112.00016           0                                                 []
# 49  2112.04871           1            ['https://github.com/Wentao-Xu/KGE-CL']

# %%
reproscreener_eval = pd.read_csv(path_corpus + 'output/reproscreener_eval.csv', dtype=object)
manual_eval = pd.read_csv(path_corpus + '../manual_eval.csv', dtype=object)
scraped_info = pd.read_csv(path_corpus + 'scrape_df_50.csv', dtype=object)
# Out:
# ---------------------------------------------------------------------------
#
# TypeError                                 Traceback (most recent call last)
#
# Cell In[14], line 1
#
# ----> 1 reproscreener_eval = pd.read_csv(path_corpus + 'output/reproscreener_eval.csv', dtype=object)
#
#       2 manual_eval = pd.read_csv(path_corpus + '../manual_eval.csv', dtype=object)
#
#       3 scraped_info = pd.read_csv(path_corpus + 'scrape_df_50.csv', dtype=object)
#
#
#
# TypeError: unsupported operand type(s) for +: 'PosixPath' and 'str'

# %%
reproscreener_eval.iloc[1]

# %%
scraped_info.iloc[1]

# %%
gunderson_vars = ["problem","objective","research_method","research_questions","pseudocode","training_data","validation_data","test_data","results","hypothesis","prediction","method_source_code","hardware_specifications","software_dependencies","experiment_setup","experiment_source_code","affiliation"]

# fraction of papers with problem
sum(reproscreener_eval.problem.values=='1.0')/len(reproscreener_eval)
# fraction of papers with objective
sum(reproscreener_eval.objective.values=='1.0')/len(reproscreener_eval)


for var in gunderson_vars:
    fraction = sum(reproscreener_eval[var].values=='1.0')/len(reproscreener_eval)
    print(var, ":", fraction)
## TODO results and experiment_source_code not implemented yet
